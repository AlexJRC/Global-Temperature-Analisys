# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexJRC/Global-Temperature-Analisys/blob/main/Temperature.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # import data

# %%
# Used data from dataset : Daily Temperature of Major Cities
#https://www.kaggle.com/datasets/sudalairajkumar/daily-temperature-of-major-cities?resource=download
#import city_temperatures.csv

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
Temperature = pd.read_csv('Temperatura/temperature/city_temperature.csv')
Temperature
# Out:
# C:\Users\alexj\AppData\Local\Temp\ipykernel_3516\3746407878.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   Temperature = pd.read_csv('Temperatura/temperature/city_temperature.csv')
#                 Region  Country                   State                  City  \
# 0               Africa  Algeria                     NaN               Algiers
# 1               Africa  Algeria                     NaN               Algiers
# 2               Africa  Algeria                     NaN               Algiers
# 3               Africa  Algeria                     NaN               Algiers
# 4               Africa  Algeria                     NaN               Algiers
# ...                ...      ...                     ...                   ...
# 2906322  North America       US  Additional Territories  San Juan Puerto Rico
# 2906323  North America       US  Additional Territories  San Juan Puerto Rico
# ...

# %%
Temperature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2906327 entries, 0 to 2906326
# Data columns (total 8 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Region          object
#  1   Country         object
#  2   State           object
#  3   City            object
#  4   Month           int64
#  5   Day             int64
#  6   Year            int64
#  7   AvgTemperature  float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 177.4+ MB

# %% [markdown]
# # Remove Duplicates datas

# %%
duplicados = Temperature[Temperature.duplicated(keep='first')]
duplicados
# Out:
#                 Region  Country     State           City  Month  Day  Year  \
# 742977          Europe  Germany       NaN        Hamburg     12    9  2007
# 742983          Europe  Germany       NaN        Hamburg     12   15  2007
# 742984          Europe  Germany       NaN        Hamburg     12   16  2007
# 742990          Europe  Germany       NaN        Hamburg     12   22  2007
# 742991          Europe  Germany       NaN        Hamburg     12   23  2007
# ...                ...      ...       ...            ...    ...  ...   ...
# 1705580  North America       US  Maryland  Washington DC      5    9  2020
# 1705581  North America       US  Maryland  Washington DC      5   10  2020
# 1705582  North America       US  Maryland  Washington DC      5   11  2020
# 1705583  North America       US  Maryland  Washington DC      5   12  2020
# 1705584  North America       US  Maryland  Washington DC      5   13  2020
#
#          AvgTemperature
# 742977            -99.0
# ...

# %%
Temperature.drop_duplicates(keep='first', inplace=True) 
Temperature
# Out:
#                 Region  Country                   State                  City  \
# 0               Africa  Algeria                     NaN               Algiers
# 1               Africa  Algeria                     NaN               Algiers
# 2               Africa  Algeria                     NaN               Algiers
# 3               Africa  Algeria                     NaN               Algiers
# 4               Africa  Algeria                     NaN               Algiers
# ...                ...      ...                     ...                   ...
# 2906322  North America       US  Additional Territories  San Juan Puerto Rico
# 2906323  North America       US  Additional Territories  San Juan Puerto Rico
# 2906324  North America       US  Additional Territories  San Juan Puerto Rico
# 2906325  North America       US  Additional Territories  San Juan Puerto Rico
# 2906326  North America       US  Additional Territories  San Juan Puerto Rico
#
# ...

# %% [markdown]
# # Tratar os dados NAN

# %%
# Temperature2=Temperature.dropna()
# Temperature2

# all datas are NaN in state

# %% [markdown]
# # Filter by Brazil Country

# %%
pais_brasil= Temperature["Country"]=="Brazil"
Brasil=Temperature[pais_brasil]
Brasil
# Out:
#                                     Region Country State       City  Month  \
# 1282775  South/Central America & Carribean  Brazil   NaN   Brasilia      1
# 1282776  South/Central America & Carribean  Brazil   NaN   Brasilia      1
# 1282777  South/Central America & Carribean  Brazil   NaN   Brasilia      1
# 1282778  South/Central America & Carribean  Brazil   NaN   Brasilia      1
# 1282779  South/Central America & Carribean  Brazil   NaN   Brasilia      1
# ...                                    ...     ...   ...        ...    ...
# 1310567  South/Central America & Carribean  Brazil   NaN  Sao Paulo      5
# 1310568  South/Central America & Carribean  Brazil   NaN  Sao Paulo      5
# 1310569  South/Central America & Carribean  Brazil   NaN  Sao Paulo      5
# 1310570  South/Central America & Carribean  Brazil   NaN  Sao Paulo      5
# 1310571  South/Central America & Carribean  Brazil   NaN  Sao Paulo      5
#
#          Day  Year  AvgTemperature
# ...

# %%
Faltantes= Brasil.isnull().sum()
Faltantes
# Out:
# Region                0
# Country               0
# State             27797
# City                  0
# Month                 0
# Day                   0
# Year                  0
# AvgTemperature        0
# dtype: int64

# %%
# How all elementes of State are NaN, i will remove this column
del Brasil["State"]

# %%
AVGM=Brasil["AvgTemperature"] >=70
AVG = Brasil[AVGM]
AVG
# Out:
#                                     Region Country       City  Month  Day  \
# 1282775  South/Central America & Carribean  Brazil   Brasilia      1    1
# 1282776  South/Central America & Carribean  Brazil   Brasilia      1    2
# 1282777  South/Central America & Carribean  Brazil   Brasilia      1    3
# 1282780  South/Central America & Carribean  Brazil   Brasilia      1    6
# 1282781  South/Central America & Carribean  Brazil   Brasilia      1    7
# ...                                    ...     ...        ...    ...  ...
# 1310530  South/Central America & Carribean  Brazil  Sao Paulo      4    2
# 1310531  South/Central America & Carribean  Brazil  Sao Paulo      4    3
# 1310534  South/Central America & Carribean  Brazil  Sao Paulo      4    6
# 1310554  South/Central America & Carribean  Brazil  Sao Paulo      4   26
# 1310558  South/Central America & Carribean  Brazil  Sao Paulo      4   30
#
#          Year  AvgTemperature
# 1282775  1995            70.9
# ...

# %%
import numpy as np
import pandas as pd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.lineplot(data=AVG["City"], y=AVG["AvgTemperature"], x=AVG["Year"], hue=AVG["City"])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='AvgTemperature'>

# %%
#In The Graph, RIO DE JANERIO is the hotter city of brazil (mean). Lets see the mouth more warm.

# %%
RioJan= AVG["City"]=="Rio de Janeiro"
RJ=AVG[RioJan]
RJ
# Out:
#                                     Region Country            City  Month  \
# 1292041  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1292042  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1292043  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1292044  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1292045  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# ...                                    ...     ...             ...    ...
# 1301299  South/Central America & Carribean  Brazil  Rio de Janeiro      5
# 1301302  South/Central America & Carribean  Brazil  Rio de Janeiro      5
# 1301303  South/Central America & Carribean  Brazil  Rio de Janeiro      5
# 1301304  South/Central America & Carribean  Brazil  Rio de Janeiro      5
# 1301305  South/Central America & Carribean  Brazil  Rio de Janeiro      5
#
#          Day  Year  AvgTemperature
# 1292041    1  1995            84.7
# ...

# %%
sns.lineplot(data=RJ["Year"], y=RJ["AvgTemperature"], x=RJ["Month"], color="Orange")
# Out:
# <AxesSubplot:xlabel='Month', ylabel='AvgTemperature'>

# %%
# The temperature is more larger in first day of year: January in Rio de Janeiro. 
#Lets see the Year more Hotter in month 1, in Rio de Janeiro

# %%
Janeiro= RJ["Month"]==1
Jan=RJ[Janeiro]
Jan
# Out:
#                                     Region Country            City  Month  \
# 1292041  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1292042  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1292043  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1292044  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1292045  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# ...                                    ...     ...             ...    ...
# 1301199  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1301200  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1301201  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1301202  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1301203  South/Central America & Carribean  Brazil  Rio de Janeiro      1
#
#          Day  Year  AvgTemperature
# 1292041    1  1995            84.7
# ...

# %%
sns.lineplot(data=Jan["City"], y=Jan["AvgTemperature"], x=Jan["Year"], color="orange")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='AvgTemperature'>

# %%
# In 2015 was the Year more hotter in RIO.
# What Day in January of 2015 is more hotter

# %%
Pas=Jan["Year"]==2015
Past=Jan[Pas]
Past
# Out:
#                                     Region Country            City  Month  \
# 1299346  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1299347  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1299348  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1299349  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1299350  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1299351  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1299352  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1299353  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1299354  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1299355  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1299356  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# 1299357  South/Central America & Carribean  Brazil  Rio de Janeiro      1
# ...

# %%
sns.lineplot(data=Past["City"], y=Past["AvgTemperature"], x=Past["Day"], color="Tomato")
# Out:
# <AxesSubplot:xlabel='Day', ylabel='AvgTemperature'>

# %%
# Day 9 of January is the day more Hotter
